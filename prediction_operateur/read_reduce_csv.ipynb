# %% [markdown]
# ## Code pour télécharger les données sur onyxia

# %%
import pandas as pd
import os

# %%
hyper_param = {
    "H": [
        230.67,
    ],
    "ya0": [
        0.00875,
    ],
    "m": 1.57,
    "file": [
        "data_john_9_case_2.csv",
    ],
    "nb_epoch": 1000,
    "save_rate": 20,
    "dynamic_weights": False,
    "lr_weights": 0.1,
    "weight_data": 0.33,
    "weight_pde": 0.33,
    "weight_border": 0.33,
    "batch_size": 10000,
    "nb_points_pde": 1000000,
    "Re": 100,
    "lr_init": 3e-4,
    "gamma_scheduler": 0.999,
    "nb_layers": 10,
    "nb_neurons": 64,
    "n_pde_test": 5000,
    "n_data_test": 5000,
    "nb_points": 144,
    "x_min": -0.1,
    "x_max": 0.1,
    "y_min": -0.1,
    "y_max": 0.1,
    "t_min": 6.5,
    "nb_period": 40,
    "nb_period_plot": 2,
    "nb_points_close_cylinder": 1,
    "rayon_close_cylinder": 0.035,
    "force_inertie_bool": True
}

# %%
names = [f"model_{k}_case_1.csv" for k in range(1,18)]
names += [f"model_{k}_case_2.csv" for k in range(1,18)]

# %%
x_min = -0.1
x_max = 0.1
y_min = -0.1
y_max = 0.1
t_min = 6.
t_max = 12.

# %%
for file in names :
    print(file)
    os.system(f'mc cp -r s3/hugopavy/{file[:-4]}_border.csv ./data/.')
    os.system(f'mc cp -r s3/hugopavy/{file} ./data/.')
    
    df = pd.read_csv('data/'+ file)
    df_modified = df.loc[
            (df["Points:0"] >= x_min)
            & (df["Points:0"] <= x_max)
            & (df["Points:1"] >= y_min)
            & (df["Points:1"] <= y_max)
            & (df["Time"] > t_min)
            & (df["Time"] < t_max)
            & (df["Points:2"] == 0.0)
            , :,
        ].copy()
    df_modified.to_csv('data/'+file, index=False)
# Out:
# model_1_case_1.csv
# `s3/hugopavy/model_1_case_1_border.csv` -> `data/model_1_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 39.05 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_1_case_1.csv` -> `data/model_1_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m23s   │ 51.10 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_2_case_1.csv
# `s3/hugopavy/model_2_case_1_border.csv` -> `data/model_2_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 28.63 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_2_case_1.csv` -> `data/model_2_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m26s   │ 45.37 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_3_case_1.csv
# `s3/hugopavy/model_3_case_1_border.csv` -> `data/model_3_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m01s   │ 12.64 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_3_case_1.csv` -> `data/model_3_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m27s   │ 44.48 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_4_case_1.csv
# `s3/hugopavy/model_4_case_1_border.csv` -> `data/model_4_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 35.07 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_4_case_1.csv` -> `data/model_4_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m23s   │ 50.85 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_5_case_1.csv
# `s3/hugopavy/model_5_case_1_border.csv` -> `data/model_5_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 35.18 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_5_case_1.csv` -> `data/model_5_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m22s   │ 53.05 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_6_case_1.csv
# `s3/hugopavy/model_6_case_1_border.csv` -> `data/model_6_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 39.26 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_6_case_1.csv` -> `data/model_6_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m19s   │ 63.88 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_7_case_1.csv
# `s3/hugopavy/model_7_case_1_border.csv` -> `data/model_7_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 25.84 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_7_case_1.csv` -> `data/model_7_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m20s   │ 60.07 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_8_case_1.csv
# `s3/hugopavy/model_8_case_1_border.csv` -> `data/model_8_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 26.02 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_8_case_1.csv` -> `data/model_8_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m24s   │ 49.93 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_9_case_1.csv
# `s3/hugopavy/model_9_case_1_border.csv` -> `data/model_9_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 18.25 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_9_case_1.csv` -> `data/model_9_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m33s   │ 35.97 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_10_case_1.csv
# `s3/hugopavy/model_10_case_1_border.csv` -> `data/model_10_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 36.28 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_10_case_1.csv` -> `data/model_10_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m20s   │ 59.01 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_11_case_1.csv
# `s3/hugopavy/model_11_case_1_border.csv` -> `data/model_11_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 24.89 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_11_case_1.csv` -> `data/model_11_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m23s   │ 52.53 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_12_case_1.csv
# `s3/hugopavy/model_12_case_1_border.csv` -> `data/model_12_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 33.25 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_12_case_1.csv` -> `data/model_12_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m25s   │ 48.07 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_13_case_1.csv
# `s3/hugopavy/model_13_case_1_border.csv` -> `data/model_13_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 41.27 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_13_case_1.csv` -> `data/model_13_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m33s   │ 36.77 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_14_case_1.csv
# `s3/hugopavy/model_14_case_1_border.csv` -> `data/model_14_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 41.71 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_14_case_1.csv` -> `data/model_14_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m21s   │ 56.28 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_15_case_1.csv
# `s3/hugopavy/model_15_case_1_border.csv` -> `data/model_15_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 25.72 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_15_case_1.csv` -> `data/model_15_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m23s   │ 50.78 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_16_case_1.csv
# `s3/hugopavy/model_16_case_1_border.csv` -> `data/model_16_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 20.77 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_16_case_1.csv` -> `data/model_16_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m24s   │ 50.12 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_17_case_1.csv
# `s3/hugopavy/model_17_case_1_border.csv` -> `data/model_17_case_1_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.90 MiB │ 17.90 MiB   │ 00m00s   │ 34.78 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_17_case_1.csv` -> `data/model_17_case_1.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m29s   │ 40.77 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_1_case_2.csv
# `s3/hugopavy/model_1_case_2_border.csv` -> `data/model_1_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 33.28 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_1_case_2.csv` -> `data/model_1_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m20s   │ 59.19 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_2_case_2.csv
# `s3/hugopavy/model_2_case_2_border.csv` -> `data/model_2_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 39.41 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_2_case_2.csv` -> `data/model_2_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m16s   │ 74.57 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_3_case_2.csv
# `s3/hugopavy/model_3_case_2_border.csv` -> `data/model_3_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬────────────┐
# │ Total     │ Transferred │ Duration │ Speed      │
# │ 17.88 MiB │ 17.88 MiB   │ 00m04s   │ 3.71 MiB/s │
# └───────────┴─────────────┴──────────┴────────────┘
# `s3/hugopavy/model_3_case_2.csv` -> `data/model_3_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m17s   │ 70.23 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_4_case_2.csv
# `s3/hugopavy/model_4_case_2_border.csv` -> `data/model_4_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 51.17 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_4_case_2.csv` -> `data/model_4_case_2.csv`
# ┌──────────┬─────────────┬──────────┬──────────────┐
# │ Total    │ Transferred │ Duration │ Speed        │
# │ 1.19 GiB │ 1.19 GiB    │ 00m10s   │ 113.94 MiB/s │
# └──────────┴─────────────┴──────────┴──────────────┘
# model_5_case_2.csv
# `s3/hugopavy/model_5_case_2_border.csv` -> `data/model_5_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 51.97 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_5_case_2.csv` -> `data/model_5_case_2.csv`
# ┌──────────┬─────────────┬──────────┬──────────────┐
# │ Total    │ Transferred │ Duration │ Speed        │
# │ 1.19 GiB │ 1.19 GiB    │ 00m11s   │ 110.22 MiB/s │
# └──────────┴─────────────┴──────────┴──────────────┘
# model_6_case_2.csv
# `s3/hugopavy/model_6_case_2_border.csv` -> `data/model_6_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 35.68 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_6_case_2.csv` -> `data/model_6_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m28s   │ 42.89 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_7_case_2.csv
# `s3/hugopavy/model_7_case_2_border.csv` -> `data/model_7_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 53.81 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_7_case_2.csv` -> `data/model_7_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m12s   │ 94.80 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_8_case_2.csv
# `s3/hugopavy/model_8_case_2_border.csv` -> `data/model_8_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 56.33 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_8_case_2.csv` -> `data/model_8_case_2.csv`
# ┌──────────┬─────────────┬──────────┬──────────────┐
# │ Total    │ Transferred │ Duration │ Speed        │
# │ 1.19 GiB │ 1.19 GiB    │ 00m11s   │ 103.15 MiB/s │
# └──────────┴─────────────┴──────────┴──────────────┘
# model_9_case_2.csv
# `s3/hugopavy/model_9_case_2_border.csv` -> `data/model_9_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.88 MiB │ 17.88 MiB   │ 00m00s   │ 39.46 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_9_case_2.csv` -> `data/model_9_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m13s   │ 92.66 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_10_case_2.csv
# `s3/hugopavy/model_10_case_2_border.csv` -> `data/model_10_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 44.76 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_10_case_2.csv` -> `data/model_10_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m12s   │ 94.01 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_11_case_2.csv
# `s3/hugopavy/model_11_case_2_border.csv` -> `data/model_11_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 39.83 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_11_case_2.csv` -> `data/model_11_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m14s   │ 83.07 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_12_case_2.csv
# `s3/hugopavy/model_12_case_2_border.csv` -> `data/model_12_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 20.71 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_12_case_2.csv` -> `data/model_12_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m12s   │ 99.72 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_13_case_2.csv
# `s3/hugopavy/model_13_case_2_border.csv` -> `data/model_13_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 48.99 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_13_case_2.csv` -> `data/model_13_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m12s   │ 99.91 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_14_case_2.csv
# `s3/hugopavy/model_14_case_2_border.csv` -> `data/model_14_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 57.68 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_14_case_2.csv` -> `data/model_14_case_2.csv`
# ┌──────────┬─────────────┬──────────┬──────────────┐
# │ Total    │ Transferred │ Duration │ Speed        │
# │ 1.19 GiB │ 1.19 GiB    │ 00m10s   │ 119.93 MiB/s │
# └──────────┴─────────────┴──────────┴──────────────┘
# model_15_case_2.csv
# `s3/hugopavy/model_15_case_2_border.csv` -> `data/model_15_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 51.43 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_15_case_2.csv` -> `data/model_15_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m13s   │ 93.60 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_16_case_2.csv
# `s3/hugopavy/model_16_case_2_border.csv` -> `data/model_16_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.89 MiB │ 17.89 MiB   │ 00m00s   │ 42.77 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_16_case_2.csv` -> `data/model_16_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m12s   │ 98.00 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
# model_17_case_2.csv
# `s3/hugopavy/model_17_case_2_border.csv` -> `data/model_17_case_2_border.csv`
# ┌───────────┬─────────────┬──────────┬─────────────┐
# │ Total     │ Transferred │ Duration │ Speed       │
# │ 17.90 MiB │ 17.90 MiB   │ 00m00s   │ 36.04 MiB/s │
# └───────────┴─────────────┴──────────┴─────────────┘
# `s3/hugopavy/model_17_case_2.csv` -> `data/model_17_case_2.csv`
# ┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 1.19 GiB │ 1.19 GiB    │ 00m13s   │ 92.13 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘

# %%
names = [f"model_5_case_2.csv"]

# %%
for file in names :
    print(file)
    os.system(f'mc cp -r s3/hugopavy/{file[:-4]}_border.csv ./data/.')
    os.system(f'mc cp -r s3/hugopavy/{file} ./data/.')
    df = pd.read_csv('data/'+ file)
    df_modified = df.loc[
            (df["Points:0"] >= x_min)
            & (df["Points:0"] <= x_max)
            & (df["Points:1"] >= y_min)
            & (df["Points:1"] <= y_max)
            & (df["Time"] > t_min)
            & (df["Time"] < t_max)
            & (df["Points:2"] == 0.0)
            , :,
        ].copy()
    df_modified.to_csv('data/'+file, index=False)
# Out:
# model_5_case_2.csv
# `s3/hugopavy/model_5_case_2_border.csv` -> `data/model_5_case_2_border.csv`
# Total: 17.88 MiB, Transferred: 17.88 MiB, Speed: 52.38 MiB/s
# `s3/hugopavy/model_5_case_2.csv` -> `data/model_5_case_2.csv`
# Total: 1.19 GiB, Transferred: 1.19 GiB, Speed: 52.72 MiB/s

# %%
file = "data_john_4_case_1.csv"

# %%
os.system(f'mc cp -r s3/fhd/{file} ./data/.')
# Out:
# mc: <ERROR> Unable to prepare URL for copying. Unable to guess the type of copy operation.
# 256

# %%
t_max
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t_max
#
# NameError: name 't_max' is not defined
